# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
plt.rcParams['figure.figsize'] = (11,7)

# %%
df_Hilbert = pd.read_excel("./resultados_matrizHilbert.xlsx")
df_Cholesky = pd.read_excel("./resultados_Cholesky.xlsx")

# %%
df_Cholesky.columns
# Out:
# Index(['dim_matriz', 'norma2 Cholesky', 'determinante Cholesky',
#        'norma2 sem Pivo', 'determinante sem Pivo', 'norma2 solucao Numpy',
#        'determinante solucao Numpy'],
#       dtype='object')

# %%
# sns.lineplot(x=df.iloc[1:], y=df.dim_matriz)
# df.plot(x="dim_matriz", y=["norma2 sem Pivo", "norma2 com Pivo", "norma2 solucao Numpy"], title="Evolucao do erro")
df_Cholesky.plot(x="dim_matriz", y=['norma2 Cholesky', 'norma2 sem Pivo', 'norma2 solucao Numpy'], title="Evolucao do erro")

# %%
df_Hilbert.columns
# Out:
# Index(['dim_matriz', 'norma2 sem Pivo', 'determinante sem Pivo',
#        'norma2 com Pivo', 'determinante com Pivo', 'norma2 solucao Numpy',
#        'determinante solucao Numpy'],
#       dtype='object')

# %%
df_Hilbert.plot(x="dim_matriz", y=['norma2 sem Pivo', 'norma2 com Pivo', 'norma2 solucao Numpy'], title="Evolucao do erro")
