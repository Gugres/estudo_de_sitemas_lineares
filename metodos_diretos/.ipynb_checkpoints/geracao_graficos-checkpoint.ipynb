# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
plt.rcParams['figure.figsize'] = (11,7)

# %%
df_Hilbert = pd.read_excel("./resultados_matrizHilbert.xlsx")
df_Cholesky = pd.read_excel("./resultados_Cholesky.xlsx")

# %%
print(df_Hilbert.columns,"\n")
print(df_Cholesky.columns)
# Out:
# Index(['dim_matriz', 'norma2 sem Pivo', 'determinante sem Pivo',
#        'norma2 com Pivo', 'determinante com Pivo', 'norma2 solucao Numpy',
#        'determinante solucao Numpy'],
#       dtype='object')
#
# Index(['dim_matriz', 'norma2 Cholesky', 'determinante Cholesky',
#        'tempo comp. Cholesky', 'norma2 sem Pivo', 'determinante sem Pivo',
#        'tempo comp. sem Pivo', 'norma2 solucao Numpy',
#        'determinante solucao Numpy', 'tempo comp. sol. Numpy'],
#       dtype='object')

# %% [markdown]
# # Parte 1

# %% [markdown]
# ## Graficos (dim_matriz X norma2)

# %%
df_Hilbert[df_Hilbert.dim_matriz <= 80].plot(x="dim_matriz", y=['norma2 sem Pivo', 'norma2 com Pivo', "norma2 com Pivo Escalado", 'norma2 solucao Numpy'], title="Evolucao do erro (Parte 1)")

# %%
aux = df_Hilbert[df_Hilbert.dim_matriz <= 80].describe()
aux[["norma2 sem Pivo","norma2 com Pivo", "norma2 com Pivo Escalado", "norma2 solucao Numpy"]]
# Out:
#        norma2 sem Pivo  norma2 com Pivo  norma2 com Pivo Escalado  \
# count     7.900000e+01     7.900000e+01              7.900000e+01
# mean      1.138150e+03     1.230417e+03              1.086361e+03
# std       2.153057e+03     3.080271e+03              2.137511e+03
# min       8.005932e-16     8.005932e-16              8.005932e-16
# 25%       5.871685e+01     5.227842e+01              5.871685e+01
# 50%       3.914121e+02     4.973457e+02              3.919891e+02
# 75%       1.064548e+03     9.316820e+02              1.046194e+03
# max       1.428824e+04     2.291615e+04              1.485411e+04
#
#        norma2 solucao Numpy
# count          7.900000e+01
# mean           1.659172e+03
# std            6.220002e+03
# min            8.005932e-16
# 25%            5.096532e+01
# 50%            1.886830e+02
# 75%            5.438470e+02
# max            4.515595e+04

# %% [markdown]
# ## Graficos (dim_matriz X determinante)

# %%
df_Hilbert.plot(x="dim_matriz", y=['determinante sem Pivo', 'determinante com Pivo', 'determinante com Pivo Escalado', 'determinante solucao Numpy'], title="Evolucao do determinate (Parte 1)")

# %% [markdown]
# # Parte 2

# %% [markdown]
# ## Graficos (dim_matriz X norma2)

# %%
df_Cholesky.plot(x="dim_matriz", y=['norma2 Cholesky', 'norma2 sem Pivo', 'norma2 solucao Numpy'], title="Evolucao do erro (Parte 2)")

# %%
aux = df_Cholesky[df_Cholesky.dim_matriz <= 80].describe()
aux[["norma2 Cholesky","norma2 sem Pivo", "norma2 solucao Numpy"]]
# Out:
#        dim_matriz  norma2 Cholesky  determinante Cholesky  \
# count   69.000000     6.900000e+01           6.900000e+01
# mean    36.000000     1.270746e-10          1.536335e+302
# std     20.062403     3.891997e-10                    inf
# min      2.000000     0.000000e+00           8.118010e+05
# 25%     19.000000     2.309711e-12           2.750690e+74
# 50%     36.000000     1.638443e-11          6.480713e+145
# 75%     53.000000     1.035641e-10          2.153181e+225
# max     70.000000     2.952116e-09          1.060014e+304
#
#        tempo comp. Cholesky  norma2 sem Pivo  determinante sem Pivo  \
# count             69.000000        69.000000           6.900000e+01
# mean               0.043677       219.527510          1.536335e+302
# std                0.044205       811.125798                    inf
# min                0.000070         1.606934           8.118010e+05
# 25%                0.005157         8.246811           2.750690e+74
# 50%                0.026815        15.737768          6.480713e+145
# 75%                0.078296        75.395627          2.153181e+225
# max                0.133889      5220.042517          1.060014e+304
#
#        tempo comp. sem Pivo  norma2 solucao Numpy  determinante solucao Numpy  \
# count             69.000000             69.000000                6.900000e+01
# mean               0.008181            219.527510               1.536335e+302
# std                0.006300            811.125797                         inf
# min                0.000029              1.606934                8.118010e+05
# 25%                0.002362              8.246811                2.750690e+74
# 50%                0.008425             15.737768               6.480713e+145
# 75%                0.012938             75.395627               2.153181e+225
# max                0.020362           5220.042515               1.060014e+304
#
#        tempo comp. sol. Numpy
# count               69.000000
# mean                 0.001105
# std                  0.002945
# min                  0.000034
# 25%                  0.000131
# 50%                  0.000268
# 75%                  0.000433
# max                  0.019323

# %% [markdown]
# ## Graficos (dim_matriz X determinante)

# %%
df_Cholesky.plot(x="dim_matriz", y=['determinante Cholesky', 'determinante sem Pivo', 'determinante solucao Numpy'], title="Evolucao do determinate (Parte 2)")

# %% [markdown]
# ## Graficos (dim_matriz X tempo_computacional)

# %%
df_Cholesky.plot(x="dim_matriz", y=["tempo comp. Cholesky", "tempo comp. sem Pivo", "tempo comp. sol. Numpy"], title="Evolucao do tempo computacional (Parte 2)")
